# %% [markdown]
# <a href="https://colab.research.google.com/github/divyajyothimadesha2008-boop/Python-basics/blob/main/Python_besics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello 🌎")
# Out:
# hello 🌎

# %%
print("divya")
# Out:
# divya

# %%
def greet( ):
    print("Hello world")
greet( )
# Out:
# Hello world

# %%
def greet(name):
    print("Hello",name)
greet("CSE")
greet("CSD")
greet("Civil")
greet("CS")
# Out:
# Hello CSE
# Hello CSD
# Hello Civil
# Hello CS
